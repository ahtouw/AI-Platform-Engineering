# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/wkaht/Documents/Revature/Project/train.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.describe(include=['object'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
data.describe(include=['int64'])
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411  ...
# std      30.202904     20.645407   456.098091   161.319273   441.866955  ...
# ...

# %%
target = data['SalePrice']
target.head(10)
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
# Name: SalePrice, dtype: int64

# %%
target.tail(10)
# Out:
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, dtype: int64

# %%
# Visualizing the distribution of Salesprice(Dependent) variable 
import seaborn as sns
sns.distplot(target,hist=True)

# %%
# Log transformation
import numpy as np
target_log  = np.log(target)

# %%
sns.distplot(target_log,hist=True)

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
prices = pd.DataFrame({"Sale Price":data["SalePrice"],"Log Sale Price ":target_log})
prices.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000278FAB33F08>,
# ...
#       dtype=object)

# %%
# drop target variable from dataset
raw_data = data
data = data.drop(["SalePrice"], axis=1)
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#MSSubClass=The building class
data['MSSubClass'] = data['MSSubClass'].apply(str)

#Changing OverallCond into a categorical variable
data['OverallCond'] = data['OverallCond'].astype(str)

#Year and month sold are transformed into categorical features.
data['YrSold'] = data['YrSold'].astype(str)
data['MoSold'] = data['MoSold'].astype(str)

# %%
# Adding total sqfootage feature 
data['TotalSF'] = data['TotalBsmtSF'] + data['1stFlrSF'] + data['2ndFlrSF']
# Removing TotalBsmtSF,1stFlrSF, 2ndFlrSF and Id
data = data.drop(["TotalBsmtSF"], axis=1)
data = data.drop(["1stFlrSF"], axis=1)
data = data.drop(["2ndFlrSF"], axis=1)
data = data.drop(["Id"], axis=1)
data.head(10)
# Out:
#   MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour  \
# 0         60       RL         65.0     8450   Pave   NaN      Reg         Lvl
# 1         20       RL         80.0     9600   Pave   NaN      Reg         Lvl
# 2         60       RL         68.0    11250   Pave   NaN      IR1         Lvl
# 3         70       RL         60.0     9550   Pave   NaN      IR1         Lvl
# 4         60       RL         84.0    14260   Pave   NaN      IR1         Lvl
# 5         50       RL         85.0    14115   Pave   NaN      IR1         Lvl
# 6         20       RL         75.0    10084   Pave   NaN      Reg         Lvl
# 7         60       RL          NaN    10382   Pave   NaN      IR1         Lvl
# 8         50       RM         51.0     6120   Pave   NaN      Reg         Lvl
# 9        190       RL         50.0     7420   Pave   NaN      Reg         Lvl
#
#   Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature MiscVal MoSold  \
# ...

# %%
# save all categorical columns in list
categorical_columns = [col for col in data.columns.values if data[col].dtype == 'object']

# dataframe with categorical features
data_cat = data[categorical_columns]
# dataframe with numerical features
data_num = data.drop(categorical_columns, axis=1)

# %%
# Using describe function in numeric dataframe 
data_num.describe()
# Out:
#        LotFrontage        LotArea  OverallQual    YearBuilt  YearRemodAdd  \
# count  1201.000000    1460.000000  1460.000000  1460.000000   1460.000000
# mean     70.049958   10516.828082     6.099315  1971.267808   1984.865753
# std      24.284752    9981.264932     1.382997    30.202904     20.645407
# min      21.000000    1300.000000     1.000000  1872.000000   1950.000000
# 25%      59.000000    7553.500000     5.000000  1954.000000   1967.000000
# 50%      69.000000    9478.500000     6.000000  1973.000000   1994.000000
# 75%      80.000000   11601.500000     7.000000  2000.000000   2004.000000
# max     313.000000  215245.000000    10.000000  2010.000000   2010.000000
#
#         MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  LowQualFinSF  ...  \
# count  1452.000000  1460.000000  1460.000000  1460.000000   1460.000000  ...
# mean    103.685262   443.639726    46.549315   567.240411      5.844521  ...
# ...

# %%
# Printing 5 head observation in categorical dataframe
data_cat.head(10)
# Out:
#   MSSubClass MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# 0         60       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1         20       RL   Pave   NaN      Reg         Lvl    AllPub       FR2
# 2         60       RL   Pave   NaN      IR1         Lvl    AllPub    Inside
# 3         70       RL   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4         60       RL   Pave   NaN      IR1         Lvl    AllPub       FR2
# 5         50       RL   Pave   NaN      IR1         Lvl    AllPub    Inside
# 6         20       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 7         60       RL   Pave   NaN      IR1         Lvl    AllPub    Corner
# 8         50       RM   Pave   NaN      Reg         Lvl    AllPub    Inside
# 9        190       RL   Pave   NaN      Reg         Lvl    AllPub    Corner
#
#   LandSlope Neighborhood  ... GarageQual GarageCond PavedDrive PoolQC  Fence  \
# ...

# %%
data_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
from scipy.stats import skew
data_num_skew = data_num.apply(lambda x: skew(x.dropna()))
data_num_skew = data_num_skew[data_num_skew > .75]

# apply log + 1 transformation for all numeric features with skewnes over .75
data_num[data_num_skew.index] = np.log1p(data_num[data_num_skew.index])

# %%
# List of variables has skewness more than 0.75
data_num_skew
# Out:
# LotFrontage       2.160866
# LotArea          12.195142
# MasVnrArea        2.666326
# BsmtFinSF1        1.683771
# BsmtFinSF2        4.250888
# BsmtUnfSF         0.919323
# LowQualFinSF      9.002080
# GrLivArea         1.365156
# BsmtHalfBath      4.099186
# KitchenAbvGr      4.483784
# WoodDeckSF        1.539792
# OpenPorchSF       2.361912
# EnclosedPorch     3.086696
# 3SsnPorch        10.293752
# ScreenPorch       4.117977
# PoolArea         14.813135
# MiscVal          24.451640
# TotalSF           1.774874
# dtype: float64

# %%
data_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
data_num = ((data_num - data_num.mean())/(data_num.max() - data_num.min()))
data_num.describe()
# Out:
#         LotFrontage       LotArea   OverallQual     YearBuilt  YearRemodAdd  \
# count  1.201000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean   1.494947e-15  4.984835e-16  1.946692e-17  2.267735e-16  1.541119e-15
# std    1.302418e-01  1.012732e-01  1.536663e-01  2.188616e-01  3.440901e-01
# min   -4.198342e-01 -3.797634e-01 -5.665906e-01 -7.193319e-01 -5.810959e-01
# 25%   -4.241893e-02 -3.544346e-02 -1.221461e-01 -1.251290e-01 -2.977626e-01
# 50%    1.556841e-02  8.988780e-03 -1.103501e-02  1.255211e-02  1.522374e-01
# 75%    7.047235e-02  4.854699e-02  1.000761e-01  2.082043e-01  3.189041e-01
# max    5.801658e-01  6.202366e-01  4.334094e-01  2.806681e-01  4.189041e-01
#
#          MasVnrArea    BsmtFinSF1    BsmtFinSF2     BsmtUnfSF  LowQualFinSF  \
# count  1.452000e+03  1.460000e+03  1.460000e+03  1.460000e+03  1.460000e+03
# mean  -2.879545e-16  4.277020e-16  1.277517e-17  5.977049e-16 -2.756072e-17
# ...

# %%
data_num.hist(figsize=(16, 20),xlabelsize=8, ylabelsize=8);

# %%
myFeatures = data['LotShape']

# %%
type(myFeatures)
# Out:
# pandas.core.series.Series

# %%
myFeatures = myFeatures.to_frame()

# %%
type(myFeatures)
# Out:
# pandas.core.frame.DataFrame

# %%
myFeatures['LandContour'] = data['LandContour']
myFeatures['Utilities'] = data['Utilities']
myFeatures['LotConfig'] = data['LotConfig']

# %%
myFeats = myFeatures

# %%
type(myFeats)
# Out:
# pandas.core.frame.DataFrame

# %%
myFeats
# Out:
#      LotShape LandContour Utilities LotConfig
# 0         Reg         Lvl    AllPub    Inside
# 1         Reg         Lvl    AllPub       FR2
# 2         IR1         Lvl    AllPub    Inside
# 3         IR1         Lvl    AllPub    Corner
# 4         IR1         Lvl    AllPub       FR2
# ...       ...         ...       ...       ...
# 1455      Reg         Lvl    AllPub    Inside
# 1456      Reg         Lvl    AllPub    Inside
# 1457      Reg         Lvl    AllPub    Inside
# 1458      Reg         Lvl    AllPub    Inside
# 1459      Reg         Lvl    AllPub    Inside
#
# [1460 rows x 4 columns]

# %%
myFeats.isnull().sum()
# Out:
# LotShape       0
# LandContour    0
# Utilities      0
# LotConfig      0
# dtype: int64

# %%
myFeats.describe()
# Out:
#        LotShape LandContour Utilities LotConfig
# count      1460        1460      1460      1460
# unique        4           4         2         5
# top         Reg         Lvl    AllPub    Inside
# freq        925        1311      1459      1052

# %%
sns.factorplot("LotShape","SalePrice",data=raw_data,hue="LotShape");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot("LandContour","SalePrice",data=raw_data,hue="LandContour");

# %%
sns.factorplot("Utilities","SalePrice",data=raw_data,hue="Utilities");

# %%
myFeats['Utilities'].describe()
# Out:
# count       1460
# unique         2
# top       AllPub
# freq        1459
# Name: Utilities, dtype: object

# %%
sns.factorplot("LotConfig","SalePrice",data=raw_data,hue="LotConfig");

# %%
sns.barplot(raw_data.LotConfig,raw_data.SalePrice)

# %%
sns.barplot(raw_data.LandContour,raw_data.SalePrice)

# %%
# Utilities
labels = raw_data["Utilities"].unique()
sizes = raw_data["Utilities"].value_counts().values
explode=[0.1,0]
parcent = 100.*sizes/sizes.sum()
labels = ['{0} - {1:1.1f} %'.format(i,j) for i,j in zip(labels, parcent)]

colors = ['yellowgreen', 'gold', 'lightblue', 'lightcoral','blue']
patches, texts= plt.pie(sizes, colors=colors,explode=explode,
                        shadow=True,startangle=90)
plt.legend(patches, labels, loc="best")

plt.title("Utilities Classification")
plt.show()

sns.violinplot(raw_data.Utilities,raw_data["SalePrice"])
plt.title("Utilities wrt Sale Price")
plt.xlabel("Utilities")
plt.ylabel("Sale Price");

# %%
# LotShape
labels = raw_data["LotShape"].unique()
sizes = raw_data["LotShape"].value_counts().values
explode=[0.1,0,0,0]
parcent = 100.*sizes/sizes.sum()
labels = ['{0} - {1:1.1f} %'.format(i,j) for i,j in zip(labels, parcent)]

colors = ['yellowgreen', 'gold', 'lightblue', 'lightcoral','blue']
patches, texts= plt.pie(sizes, colors=colors,explode=explode,
                        shadow=True,startangle=90)
plt.legend(patches, labels, loc="best")

plt.title("LotShape Classification")
plt.show()

sns.violinplot(raw_data.LotShape,raw_data["SalePrice"])
plt.title("LotShape wrt Sale Price")
plt.xlabel("LotShape")
plt.ylabel("Sale Price");

# %%
# LandContour
labels = raw_data["LandContour"].unique()
sizes = raw_data["LandContour"].value_counts().values
explode=[0.1,0,0,0]
parcent = 100.*sizes/sizes.sum()
labels = ['{0} - {1:1.1f} %'.format(i,j) for i,j in zip(labels, parcent)]

colors = ['yellowgreen', 'gold', 'lightblue', 'lightcoral','blue']
patches, texts= plt.pie(sizes, colors=colors,explode=explode,
                        shadow=True,startangle=90)
plt.legend(patches, labels, loc="best")

plt.title("LandContour Classification")
plt.show()

sns.violinplot(raw_data.LandContour,raw_data["SalePrice"])
plt.title("LandContour wrt Sale Price")
plt.xlabel("LandContour")
plt.ylabel("Sale Price");

# %%
# LotConfig
labels = raw_data["LotConfig"].unique()
sizes = raw_data["LotConfig"].value_counts().values
explode=[0.1,0,0,0,0]
parcent = 100.*sizes/sizes.sum()
labels = ['{0} - {1:1.1f} %'.format(i,j) for i,j in zip(labels, parcent)]

colors = ['yellowgreen', 'gold', 'lightblue', 'lightcoral','blue']
patches, texts= plt.pie(sizes, colors=colors,explode=explode,
                        shadow=True,startangle=90)
plt.legend(patches, labels, loc="best")

plt.title("LotConfig Classification")
plt.show()

sns.violinplot(raw_data.LotConfig,raw_data["SalePrice"])
plt.title("LotConfig wrt Sale Price")
plt.xlabel("LotConfig")
plt.ylabel("Sale Price");

# %%
pd.__version__
# Out:
# '0.25.3'

# %%
myFeats.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import seaborn as sns
sns.catplot(x="LotConfig", y="Sale Price", kind="swarm", data=raw_data["SalePrice"]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2ad068921b05> in <module>
#       1 import seaborn as sns
# ----> 2 sns.catplot(x="LotConfig", y="Sale Price", kind="swarm", data=raw_data["SalePrice"]);
#
# NameError: name 'raw_data' is not defined

# %%
pltd['LotConfig'] = raw_data['LotConfig']
pltd['SalePrice'] = raw_data["SalePrice"]

# %%
pltd = pd.DataFrame()

# %%
pltd['LotConfig'] = raw_data['LotConfig']
pltd['SalePrice'] = raw_data["SalePrice"]

# %%
pltd.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
pltd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
# LotConfig    1460 non-null object
# SalePrice    1460 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 22.9+ KB

# %%
sns.catplot(raw_data.LotConfig,raw_data["SalePrice"]);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f3d290cac2a2> in <module>
# ----> 1 sns.catplot(raw_data.LotConfig,raw_data["SalePrice"]);
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3750
#    3751     # Initialize the facets
# -> 3752     g = FacetGrid(**facet_kws)
#    3753
#    3754     # Draw the plot onto the facets
#
# ...

# %%
sns.catplot(x='continent', y='lifeExp', 
            data=pltd,jitter='0.25')

# %%
sns.catplot(x='LotConfig', y='SalePrice', kind="swarm",
            data=pltd);

# %%
sns.catplot(x='Utilities', y='SalePrice', kind="swarm",
            data=raw_data);

# %%
sns.catplot(x='LotShape', y='SalePrice', kind="swarm",
            data=raw_data);

# %%
sns.catplot(x='LandContour', y='SalePrice', kind="swarm",
            data=raw_data);
